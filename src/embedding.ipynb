# %%
import glob
import json
import os
import sys
from pathlib import Path

import librosa
import numpy as np
import openl3
import soundfile as sf
import tensorflow as tf

# %%
# Filepath to get audio files from 
ROOT = Path("../data/fma_small")
files = sorted(glob.glob(os.path.join(ROOT, "**", "*.mp3"), recursive=True))


# Filepath to write embeddings to (change if new embedding folder desired)
out = Path("embeds_small").mkdir(exist_ok=True) or Path("embeds_small")
files = sorted(ROOT.rglob("*.mp3"))
n = len(files)
indexf = out / "index.jsonl"

# %%
embeds, labels = [], []
processed_count = 0


gpus = tf.config.list_physical_devices('GPU')
for gpu in gpus:
    # Let TF grab memory lazily, expanding on demand
    tf.config.experimental.set_memory_growth(gpu, True)


# Count existing files to show progress correctly
existing_files = sum(1 for file in files if (out / f"{file.stem}.npy").exists())
print(f"Found {existing_files} already processed files, {len(files) - existing_files} remaining")

for i, file in enumerate(files):

    stem = file.stem # 12345 from 12345.mp3
    npy_path = out / f"{stem}.npy" # Create embedding filename

    # File exists
    if npy_path.exists(): 
        print(f"Skipping {file} - already processed [{i+1}/{len(files)}]")
        continue
    
    try:
        audio, sr = librosa.load(file, sr=None, mono=True)
    except Exception as e:
        print(f"Error loading {file}: {e}")
        continue

    # Preprocessing:
    audio_48 = librosa.resample(audio, orig_sr=sr, target_sr=48000, res_type="soxr_vhq") # Resample to 48 kHz 
    audio_mono = librosa.to_mono(audio_48) # Ensure mono channel   
    peak = np.max(np.abs(audio_mono))  # Find peak amplitude
    audio_norm = 0.891 * audio_mono / peak # Normalisation

    print(f"Processing {file} ({i+1}/{len(files)})")
    i += 1
   
    # Embedding extraction:
    embedding, ts = openl3.get_audio_embedding(
        audio_48, 48000, 
        content_type='music', 
        input_repr='mel256', 
        embedding_size=512, # Change to 6144 for larger embeddings
        hop_size=0.1, 
        center=True, 
        batch_size=1
    )

    np.save(npy_path, embedding.astype(np.float32))      # atomic write

    # log minimal metadata for later reconstruction
    with indexf.open("a") as f:
        json.dump({"track_id": int(stem),
                    "n_frames": len(embedding),
                    "path": str(npy_path)}, f)
        f.write("\n")

    print(f"[{i}/{n}] {stem}: wrote {embedding.shape}")

    embeds.append(embedding)
    labels.append(file)
# Out:
# Found 7997 already processed files, 3 remaining
# Skipping ..\data\fma_small\000\000002.mp3 - already processed [1/8000]
# Skipping ..\data\fma_small\000\000005.mp3 - already processed [2/8000]
# Skipping ..\data\fma_small\000\000010.mp3 - already processed [3/8000]
# Skipping ..\data\fma_small\000\000140.mp3 - already processed [4/8000]
# Skipping ..\data\fma_small\000\000141.mp3 - already processed [5/8000]
# Skipping ..\data\fma_small\000\000148.mp3 - already processed [6/8000]
# Skipping ..\data\fma_small\000\000182.mp3 - already processed [7/8000]
# Skipping ..\data\fma_small\000\000190.mp3 - already processed [8/8000]
# Skipping ..\data\fma_small\000\000193.mp3 - already processed [9/8000]
# Skipping ..\data\fma_small\000\000194.mp3 - already processed [10/8000]
# Skipping ..\data\fma_small\000\000197.mp3 - already processed [11/8000]
# Skipping ..\data\fma_small\000\000200.mp3 - already processed [12/8000]
# Skipping ..\data\fma_small\000\000203.mp3 - already processed [13/8000]
# Skipping ..\data\fma_small\000\000204.mp3 - already processed [14/8000]
# Skipping ..\data\fma_small\000\000207.mp3 - already processed [15/8000]
# Skipping ..\data\fma_small\000\000210.mp3 - already processed [16/8000]
# Skipping ..\data\fma_small\000\000211.mp3 - already processed [17/8000]
# Skipping ..\data\fma_small\000\000212.mp3 - already processed [18/8000]
# Skipping ..\data\fma_small\000\000213.mp3 - already processed [19/8000]
# Skipping ..\data\fma_small\000\000255.mp3 - already processed [20/8000]
# Skipping ..\data\fma_small\000\000256.mp3 - already processed [21/8000]
# Skipping ..\data\fma_small\000\000368.mp3 - already processed [22/8000]
# Skipping ..\data\fma_small\000\000424.mp3 - already processed [23/8000]
# Skipping ..\data\fma_small\000\000459.mp3 - already processed [24/8000]
# Skipping ..\data\fma_small\000\000534.mp3 - already processed [25/8000]
# Skipping ..\data\fma_small\000\000540.mp3 - already processed [26/8000]
# Skipping ..\data\fma_small\000\000546.mp3 - already processed [27/8000]
# Skipping ..\data\fma_small\000\000574.mp3 - already processed [28/8000]
# Skipping ..\data\fma_small\000\000602.mp3 - already processed [29/8000]
# Skipping ..\data\fma_small\000\000615.mp3 - already processed [30/8000]
# Skipping ..\data\fma_small\000\000620.mp3 - already processed [31/8000]
# Skipping ..\data\fma_small\000\000621.mp3 - already processed [32/8000]
# Skipping ..\data\fma_small\000\000625.mp3 - already processed [33/8000]
# Skipping ..\data\fma_small\000\000666.mp3 - already processed [34/8000]
# Skipping ..\data\fma_small\000\000667.mp3 - already processed [35/8000]
# Skipping ..\data\fma_small\000\000676.mp3 - already processed [36/8000]
# Skipping ..\data\fma_small\000\000690.mp3 - already processed [37/8000]
# Skipping ..\data\fma_small\000\000694.mp3 - already processed [38/8000]
# Skipping ..\data\fma_small\000\000695.mp3 - already processed [39/8000]
# Skipping ..\data\fma_small\000\000704.mp3 - already processed [40/8000]
# Skipping ..\data\fma_small\000\000705.mp3 - already processed [41/8000]
# Skipping ..\data\fma_small\000\000706.mp3 - already processed [42/8000]
# Skipping ..\data\fma_small\000\000707.mp3 - already processed [43/8000]
# Skipping ..\data\fma_small\000\000708.mp3 - already processed [44/8000]
# Skipping ..\data\fma_small\000\000709.mp3 - already processed [45/8000]
# Skipping ..\data\fma_small\000\000714.mp3 - already processed [46/8000]
# Skipping ..\data\fma_small\000\000715.mp3 - already processed [47/8000]
# Skipping ..\data\fma_small\000\000716.mp3 - already processed [48/8000]
# Skipping ..\data\fma_small\000\000718.mp3 - already processed [49/8000]
# Skipping ..\data\fma_small\000\000777.mp3 - already processed [50/8000]
# Skipping ..\data\fma_small\000\000814.mp3 - already processed [51/8000]
# Skipping ..\data\fma_small\000\000821.mp3 - already processed [52/8000]
# Skipping ..\data\fma_small\000\000822.mp3 - already processed [53/8000]
# Skipping ..\data\fma_small\000\000825.mp3 - already processed [54/8000]
# Skipping ..\data\fma_small\000\000853.mp3 - already processed [55/8000]
# Skipping ..\data\fma_small\000\000890.mp3 - already processed [56/8000]
# Skipping ..\data\fma_small\000\000892.mp3 - already processed [57/8000]
# Skipping ..\data\fma_small\000\000897.mp3 - already processed [58/8000]
# Skipping ..\data\fma_small\000\000993.mp3 - already processed [59/8000]
# Skipping ..\data\fma_small\000\000995.mp3 - already processed [60/8000]
# Skipping ..\data\fma_small\000\000997.mp3 - already processed [61/8000]
# Skipping ..\data\fma_small\000\000998.mp3 - already processed [62/8000]
# Skipping ..\data\fma_small\001\001039.mp3 - already processed [63/8000]
# Skipping ..\data\fma_small\001\001040.mp3 - already processed [64/8000]
# Skipping ..\data\fma_small\001\001066.mp3 - already processed [65/8000]
# Skipping ..\data\fma_small\001\001069.mp3 - already processed [66/8000]
# Skipping ..\data\fma_small\001\001073.mp3 - already processed [67/8000]
# Skipping ..\data\fma_small\001\001075.mp3 - already processed [68/8000]
# Skipping ..\data\fma_small\001\001082.mp3 - already processed [69/8000]
# Skipping ..\data\fma_small\001\001083.mp3 - already processed [70/8000]
# Skipping ..\data\fma_small\001\001087.mp3 - already processed [71/8000]
# Skipping ..\data\fma_small\001\001102.mp3 - already processed [72/8000]
# Skipping ..\data\fma_small\001\001193.mp3 - already processed [73/8000]
# Skipping ..\data\fma_small\001\001195.mp3 - already processed [74/8000]
# Skipping ..\data\fma_small\001\001196.mp3 - already processed [75/8000]
# Skipping ..\data\fma_small\001\001197.mp3 - already processed [76/8000]
# Skipping ..\data\fma_small\001\001249.mp3 - already processed [77/8000]
# Skipping ..\data\fma_small\001\001259.mp3 - already processed [78/8000]
# Skipping ..\data\fma_small\001\001270.mp3 - already processed [79/8000]
# Skipping ..\data\fma_small\001\001276.mp3 - already processed [80/8000]
# Skipping ..\data\fma_small\001\001277.mp3 - already processed [81/8000]
# Skipping ..\data\fma_small\001\001278.mp3 - already processed [82/8000]
# Skipping ..\data\fma_small\001\001417.mp3 - already processed [83/8000]
# Skipping ..\data\fma_small\001\001427.mp3 - already processed [84/8000]
# Skipping ..\data\fma_small\001\001443.mp3 - already processed [85/8000]
# Skipping ..\data\fma_small\001\001482.mp3 - already processed [86/8000]
# Skipping ..\data\fma_small\001\001510.mp3 - already processed [87/8000]
# Skipping ..\data\fma_small\001\001544.mp3 - already processed [88/8000]
# Skipping ..\data\fma_small\001\001642.mp3 - already processed [89/8000]
# Skipping ..\data\fma_small\001\001644.mp3 - already processed [90/8000]
# Skipping ..\data\fma_small\001\001649.mp3 - already processed [91/8000]
# Skipping ..\data\fma_small\001\001661.mp3 - already processed [92/8000]
# Skipping ..\data\fma_small\001\001663.mp3 - already processed [93/8000]
# Skipping ..\data\fma_small\001\001666.mp3 - already processed [94/8000]
# Skipping ..\data\fma_small\001\001673.mp3 - already processed [95/8000]
# Skipping ..\data\fma_small\001\001680.mp3 - already processed [96/8000]
# Skipping ..\data\fma_small\001\001681.mp3 - already processed [97/8000]
# Skipping ..\data\fma_small\001\001682.mp3 - already processed [98/8000]
# Skipping ..\data\fma_small\001\001683.mp3 - already processed [99/8000]
# Skipping ..\data\fma_small\001\001684.mp3 - already processed [100/8000]
# Skipping ..\data\fma_small\001\001685.mp3 - already processed [101/8000]
# Skipping ..\data\fma_small\001\001686.mp3 - already processed [102/8000]
# Skipping ..\data\fma_small\001\001687.mp3 - already processed [103/8000]
# Skipping ..\data\fma_small\001\001688.mp3 - already processed [104/8000]
# Skipping ..\data\fma_small\001\001689.mp3 - already processed [105/8000]
# Skipping ..\data\fma_small\001\001701.mp3 - already processed [106/8000]
# Skipping ..\data\fma_small\001\001702.mp3 - already processed [107/8000]
# Skipping ..\data\fma_small\001\001703.mp3 - already processed [108/8000]
# Skipping ..\data\fma_small\001\001704.mp3 - already processed [109/8000]
# Skipping ..\data\fma_small\001\001706.mp3 - already processed [110/8000]
# Skipping ..\data\fma_small\001\001720.mp3 - already processed [111/8000]
# Skipping ..\data\fma_small\001\001732.mp3 - already processed [112/8000]
# Skipping ..\data\fma_small\001\001733.mp3 - already processed [113/8000]
# Skipping ..\data\fma_small\001\001735.mp3 - already processed [114/8000]
# Skipping ..\data\fma_small\001\001736.mp3 - already processed [115/8000]
# Skipping ..\data\fma_small\001\001883.mp3 - already processed [116/8000]
# Skipping ..\data\fma_small\001\001891.mp3 - already processed [117/8000]
# Skipping ..\data\fma_small\001\001893.mp3 - already processed [118/8000]
# Skipping ..\data\fma_small\001\001924.mp3 - already processed [119/8000]
# Skipping ..\data\fma_small\001\001925.mp3 - already processed [120/8000]
# Skipping ..\data\fma_small\001\001929.mp3 - already processed [121/8000]
# Skipping ..\data\fma_small\001\001930.mp3 - already processed [122/8000]
# Skipping ..\data\fma_small\002\002012.mp3 - already processed [123/8000]
# Skipping ..\data\fma_small\002\002096.mp3 - already processed [124/8000]
# Skipping ..\data\fma_small\002\002097.mp3 - already processed [125/8000]
# Skipping ..\data\fma_small\002\002099.mp3 - already processed [126/8000]
# Skipping ..\data\fma_small\003\003263.mp3 - already processed [127/8000]
# Skipping ..\data\fma_small\003\003264.mp3 - already processed [128/8000]
# Skipping ..\data\fma_small\003\003265.mp3 - already processed [129/8000]
# Skipping ..\data\fma_small\003\003266.mp3 - already processed [130/8000]
# Skipping ..\data\fma_small\003\003270.mp3 - already processed [131/8000]
# Skipping ..\data\fma_small\003\003271.mp3 - already processed [132/8000]
# Skipping ..\data\fma_small\003\003272.mp3 - already processed [133/8000]
# Skipping ..\data\fma_small\003\003273.mp3 - already processed [134/8000]
# Skipping ..\data\fma_small\003\003274.mp3 - already processed [135/8000]
# Skipping ..\data\fma_small\003\003492.mp3 - already processed [136/8000]
# Skipping ..\data\fma_small\003\003532.mp3 - already processed [137/8000]
# Skipping ..\data\fma_small\003\003533.mp3 - already processed [138/8000]
# Skipping ..\data\fma_small\003\003534.mp3 - already processed [139/8000]
# Skipping ..\data\fma_small\003\003535.mp3 - already processed [140/8000]
# Skipping ..\data\fma_small\003\003537.mp3 - already processed [141/8000]
# Skipping ..\data\fma_small\003\003538.mp3 - already processed [142/8000]
# Skipping ..\data\fma_small\003\003573.mp3 - already processed [143/8000]
# Skipping ..\data\fma_small\003\003598.mp3 - already processed [144/8000]
# Skipping ..\data\fma_small\003\003624.mp3 - already processed [145/8000]
# Skipping ..\data\fma_small\003\003707.mp3 - already processed [146/8000]
# Skipping ..\data\fma_small\003\003708.mp3 - already processed [147/8000]
# Skipping ..\data\fma_small\003\003720.mp3 - already processed [148/8000]
# Skipping ..\data\fma_small\003\003721.mp3 - already processed [149/8000]
# Skipping ..\data\fma_small\003\003722.mp3 - already processed [150/8000]
# Skipping ..\data\fma_small\003\003724.mp3 - already processed [151/8000]
# Skipping ..\data\fma_small\003\003725.mp3 - already processed [152/8000]
# Skipping ..\data\fma_small\003\003761.mp3 - already processed [153/8000]
# Skipping ..\data\fma_small\003\003762.mp3 - already processed [154/8000]
# Skipping ..\data\fma_small\003\003763.mp3 - already processed [155/8000]
# Skipping ..\data\fma_small\003\003765.mp3 - already processed [156/8000]
# Skipping ..\data\fma_small\003\003766.mp3 - already processed [157/8000]
# Skipping ..\data\fma_small\003\003775.mp3 - already processed [158/8000]
# Skipping ..\data\fma_small\003\003776.mp3 - already processed [159/8000]
# Skipping ..\data\fma_small\003\003777.mp3 - already processed [160/8000]
# Skipping ..\data\fma_small\003\003778.mp3 - already processed [161/8000]
# Skipping ..\data\fma_small\003\003779.mp3 - already processed [162/8000]
# Skipping ..\data\fma_small\003\003832.mp3 - already processed [163/8000]
# Skipping ..\data\fma_small\003\003833.mp3 - already processed [164/8000]
# Skipping ..\data\fma_small\003\003840.mp3 - already processed [165/8000]
# Skipping ..\data\fma_small\003\003880.mp3 - already processed [166/8000]
# Skipping ..\data\fma_small\003\003895.mp3 - already processed [167/8000]
# Skipping ..\data\fma_small\003\003896.mp3 - already processed [168/8000]
# Skipping ..\data\fma_small\003\003904.mp3 - already processed [169/8000]
# Skipping ..\data\fma_small\003\003905.mp3 - already processed [170/8000]
# Skipping ..\data\fma_small\003\003906.mp3 - already processed [171/8000]
# Skipping ..\data\fma_small\003\003908.mp3 - already processed [172/8000]
# Skipping ..\data\fma_small\003\003909.mp3 - already processed [173/8000]
# Skipping ..\data\fma_small\003\003910.mp3 - already processed [174/8000]
# Skipping ..\data\fma_small\003\003911.mp3 - already processed [175/8000]
# Skipping ..\data\fma_small\003\003912.mp3 - already processed [176/8000]
# Skipping ..\data\fma_small\003\003913.mp3 - already processed [177/8000]
# Skipping ..\data\fma_small\003\003920.mp3 - already processed [178/8000]
# Skipping ..\data\fma_small\003\003921.mp3 - already processed [179/8000]
# Skipping ..\data\fma_small\003\003950.mp3 - already processed [180/8000]
# Skipping ..\data\fma_small\004\004013.mp3 - already processed [181/8000]
# Skipping ..\data\fma_small\004\004017.mp3 - already processed [182/8000]
# Skipping ..\data\fma_small\004\004022.mp3 - already processed [183/8000]
# Skipping ..\data\fma_small\004\004037.mp3 - already processed [184/8000]
# Skipping ..\data\fma_small\004\004066.mp3 - already processed [185/8000]
# Skipping ..\data\fma_small\004\004067.mp3 - already processed [186/8000]
# Skipping ..\data\fma_small\004\004068.mp3 - already processed [187/8000]
# Skipping ..\data\fma_small\004\004069.mp3 - already processed [188/8000]
# Skipping ..\data\fma_small\004\004070.mp3 - already processed [189/8000]
# Skipping ..\data\fma_small\004\004071.mp3 - already processed [190/8000]
# Skipping ..\data\fma_small\004\004072.mp3 - already processed [191/8000]
# Skipping ..\data\fma_small\004\004073.mp3 - already processed [192/8000]
# Skipping ..\data\fma_small\004\004074.mp3 - already processed [193/8000]
# Skipping ..\data\fma_small\004\004075.mp3 - already processed [194/8000]
# Skipping ..\data\fma_small\004\004076.mp3 - already processed [195/8000]
# Skipping ..\data\fma_small\004\004077.mp3 - already processed [196/8000]
# Skipping ..\data\fma_small\004\004078.mp3 - already processed [197/8000]
# Skipping ..\data\fma_small\004\004079.mp3 - already processed [198/8000]
# Skipping ..\data\fma_small\004\004080.mp3 - already processed [199/8000]
# Skipping ..\data\fma_small\004\004091.mp3 - already processed [200/8000]
# Skipping ..\data\fma_small\004\004092.mp3 - already processed [201/8000]
# Skipping ..\data\fma_small\004\004093.mp3 - already processed [202/8000]
# Skipping ..\data\fma_small\004\004094.mp3 - already processed [203/8000]
# Skipping ..\data\fma_small\004\004095.mp3 - already processed [204/8000]
# Skipping ..\data\fma_small\004\004096.mp3 - already processed [205/8000]
# Skipping ..\data\fma_small\004\004097.mp3 - already processed [206/8000]
# Skipping ..\data\fma_small\004\004098.mp3 - already processed [207/8000]
# Skipping ..\data\fma_small\004\004099.mp3 - already processed [208/8000]
# Skipping ..\data\fma_small\004\004100.mp3 - already processed [209/8000]
# Skipping ..\data\fma_small\004\004101.mp3 - already processed [210/8000]
# Skipping ..\data\fma_small\004\004102.mp3 - already processed [211/8000]
# Skipping ..\data\fma_small\004\004103.mp3 - already processed [212/8000]
# Skipping ..\data\fma_small\004\004108.mp3 - already processed [213/8000]
# Skipping ..\data\fma_small\004\004232.mp3 - already processed [214/8000]
# Skipping ..\data\fma_small\004\004233.mp3 - already processed [215/8000]
# Skipping ..\data\fma_small\004\004234.mp3 - already processed [216/8000]
# Skipping ..\data\fma_small\004\004235.mp3 - already processed [217/8000]
# Skipping ..\data\fma_small\004\004236.mp3 - already processed [218/8000]
# Skipping ..\data\fma_small\004\004239.mp3 - already processed [219/8000]
# Skipping ..\data\fma_small\004\004450.mp3 - already processed [220/8000]
# Skipping ..\data\fma_small\004\004507.mp3 - already processed [221/8000]
# Skipping ..\data\fma_small\004\004508.mp3 - already processed [222/8000]
# Skipping ..\data\fma_small\004\004509.mp3 - already processed [223/8000]
# Skipping ..\data\fma_small\004\004510.mp3 - already processed [224/8000]
# Skipping ..\data\fma_small\004\004511.mp3 - already processed [225/8000]
# Skipping ..\data\fma_small\004\004519.mp3 - already processed [226/8000]
# Skipping ..\data\fma_small\004\004520.mp3 - already processed [227/8000]
# Skipping ..\data\fma_small\004\004521.mp3 - already processed [228/8000]
# Skipping ..\data\fma_small\004\004522.mp3 - already processed [229/8000]
# Skipping ..\data\fma_small\004\004682.mp3 - already processed [230/8000]
# Skipping ..\data\fma_small\004\004684.mp3 - already processed [231/8000]
# Skipping ..\data\fma_small\004\004685.mp3 - already processed [232/8000]
# Skipping ..\data\fma_small\004\004688.mp3 - already processed [233/8000]
# Skipping ..\data\fma_small\004\004777.mp3 - already processed [234/8000]
# Skipping ..\data\fma_small\004\004778.mp3 - already processed [235/8000]
# Skipping ..\data\fma_small\004\004779.mp3 - already processed [236/8000]
# Skipping ..\data\fma_small\004\004780.mp3 - already processed [237/8000]
# Skipping ..\data\fma_small\004\004781.mp3 - already processed [238/8000]
# Skipping ..\data\fma_small\004\004782.mp3 - already processed [239/8000]
# Skipping ..\data\fma_small\004\004784.mp3 - already processed [240/8000]
# Skipping ..\data\fma_small\004\004785.mp3 - already processed [241/8000]
# Skipping ..\data\fma_small\004\004786.mp3 - already processed [242/8000]
# Skipping ..\data\fma_small\004\004787.mp3 - already processed [243/8000]
# Skipping ..\data\fma_small\004\004788.mp3 - already processed [244/8000]
# Skipping ..\data\fma_small\004\004799.mp3 - already processed [245/8000]
# Skipping ..\data\fma_small\004\004835.mp3 - already processed [246/8000]
# Skipping ..\data\fma_small\004\004836.mp3 - already processed [247/8000]
# Skipping ..\data\fma_small\004\004838.mp3 - already processed [248/8000]
# Skipping ..\data\fma_small\004\004846.mp3 - already processed [249/8000]
# Skipping ..\data\fma_small\004\004848.mp3 - already processed [250/8000]
# Skipping ..\data\fma_small\004\004849.mp3 - already processed [251/8000]
# Skipping ..\data\fma_small\005\005006.mp3 - already processed [252/8000]
# Skipping ..\data\fma_small\005\005156.mp3 - already processed [253/8000]
# Skipping ..\data\fma_small\005\005157.mp3 - already processed [254/8000]
# Skipping ..\data\fma_small\005\005158.mp3 - already processed [255/8000]
# Skipping ..\data\fma_small\005\005159.mp3 - already processed [256/8000]
# Skipping ..\data\fma_small\005\005169.mp3 - already processed [257/8000]
# Skipping ..\data\fma_small\005\005170.mp3 - already processed [258/8000]
# Skipping ..\data\fma_small\005\005171.mp3 - already processed [259/8000]
# Skipping ..\data\fma_small\005\005191.mp3 - already processed [260/8000]
# Skipping ..\data\fma_small\005\005264.mp3 - already processed [261/8000]
# Skipping ..\data\fma_small\005\005268.mp3 - already processed [262/8000]
# Skipping ..\data\fma_small\005\005376.mp3 - already processed [263/8000]
# Skipping ..\data\fma_small\005\005381.mp3 - already processed [264/8000]
# Skipping ..\data\fma_small\005\005521.mp3 - already processed [265/8000]
# Skipping ..\data\fma_small\005\005879.mp3 - already processed [266/8000]
# Skipping ..\data\fma_small\005\005936.mp3 - already processed [267/8000]
# Skipping ..\data\fma_small\005\005940.mp3 - already processed [268/8000]
# Skipping ..\data\fma_small\006\006329.mp3 - already processed [269/8000]
# Skipping ..\data\fma_small\006\006330.mp3 - already processed [270/8000]
# Skipping ..\data\fma_small\006\006331.mp3 - already processed [271/8000]
# Skipping ..\data\fma_small\006\006332.mp3 - already processed [272/8000]
# Skipping ..\data\fma_small\006\006333.mp3 - already processed [273/8000]
# Skipping ..\data\fma_small\006\006342.mp3 - already processed [274/8000]
# Skipping ..\data\fma_small\006\006354.mp3 - already processed [275/8000]
# Skipping ..\data\fma_small\006\006357.mp3 - already processed [276/8000]
# Skipping ..\data\fma_small\006\006358.mp3 - already processed [277/8000]
# Skipping ..\data\fma_small\006\006360.mp3 - already processed [278/8000]
# Skipping ..\data\fma_small\006\006363.mp3 - already processed [279/8000]
# Skipping ..\data\fma_small\006\006366.mp3 - already processed [280/8000]
# Skipping ..\data\fma_small\006\006367.mp3 - already processed [281/8000]
# Skipping ..\data\fma_small\006\006368.mp3 - already processed [282/8000]
# Skipping ..\data\fma_small\006\006370.mp3 - already processed [283/8000]
# Skipping ..\data\fma_small\006\006372.mp3 - already processed [284/8000]
# Skipping ..\data\fma_small\006\006373.mp3 - already processed [285/8000]
# Skipping ..\data\fma_small\006\006376.mp3 - already processed [286/8000]
# Skipping ..\data\fma_small\006\006379.mp3 - already processed [287/8000]
# Skipping ..\data\fma_small\006\006380.mp3 - already processed [288/8000]
# Skipping ..\data\fma_small\006\006381.mp3 - already processed [289/8000]
# Skipping ..\data\fma_small\006\006382.mp3 - already processed [290/8000]
# Skipping ..\data\fma_small\006\006383.mp3 - already processed [291/8000]
# Skipping ..\data\fma_small\006\006385.mp3 - already processed [292/8000]
# Skipping ..\data\fma_small\006\006387.mp3 - already processed [293/8000]
# Skipping ..\data\fma_small\006\006389.mp3 - already processed [294/8000]
# Skipping ..\data\fma_small\006\006390.mp3 - already processed [295/8000]
# Skipping ..\data\fma_small\006\006393.mp3 - already processed [296/8000]
# Skipping ..\data\fma_small\006\006394.mp3 - already processed [297/8000]
# Skipping ..\data\fma_small\006\006396.mp3 - already processed [298/8000]
# Skipping ..\data\fma_small\006\006406.mp3 - already processed [299/8000]
# Skipping ..\data\fma_small\006\006407.mp3 - already processed [300/8000]
# Skipping ..\data\fma_small\006\006439.mp3 - already processed [301/8000]
# Skipping ..\data\fma_small\006\006440.mp3 - already processed [302/8000]
# Skipping ..\data\fma_small\006\006442.mp3 - already processed [303/8000]
# Skipping ..\data\fma_small\006\006443.mp3 - already processed [304/8000]
# Skipping ..\data\fma_small\006\006448.mp3 - already processed [305/8000]
# Skipping ..\data\fma_small\006\006459.mp3 - already processed [306/8000]
# Skipping ..\data\fma_small\006\006461.mp3 - already processed [307/8000]
# Skipping ..\data\fma_small\006\006463.mp3 - already processed [308/8000]
# Skipping ..\data\fma_small\006\006467.mp3 - already processed [309/8000]
# Skipping ..\data\fma_small\006\006469.mp3 - already processed [310/8000]
# Skipping ..\data\fma_small\006\006517.mp3 - already processed [311/8000]
# Skipping ..\data\fma_small\006\006519.mp3 - already processed [312/8000]
# Skipping ..\data\fma_small\006\006603.mp3 - already processed [313/8000]
# Skipping ..\data\fma_small\006\006605.mp3 - already processed [314/8000]
# Skipping ..\data\fma_small\006\006606.mp3 - already processed [315/8000]
# Skipping ..\data\fma_small\006\006607.mp3 - already processed [316/8000]
# Skipping ..\data\fma_small\006\006608.mp3 - already processed [317/8000]
# Skipping ..\data\fma_small\006\006609.mp3 - already processed [318/8000]
# Skipping ..\data\fma_small\006\006610.mp3 - already processed [319/8000]
# Skipping ..\data\fma_small\006\006611.mp3 - already processed [320/8000]
# Skipping ..\data\fma_small\006\006674.mp3 - already processed [321/8000]
# Skipping ..\data\fma_small\006\006675.mp3 - already processed [322/8000]
# Skipping ..\data\fma_small\006\006677.mp3 - already processed [323/8000]
# Skipping ..\data\fma_small\006\006679.mp3 - already processed [324/8000]
# Skipping ..\data\fma_small\006\006680.mp3 - already processed [325/8000]
# Skipping ..\data\fma_small\006\006684.mp3 - already processed [326/8000]
# Skipping ..\data\fma_small\006\006762.mp3 - already processed [327/8000]
# Skipping ..\data\fma_small\006\006776.mp3 - already processed [328/8000]
# Skipping ..\data\fma_small\006\006778.mp3 - already processed [329/8000]
# Skipping ..\data\fma_small\006\006779.mp3 - already processed [330/8000]
# Skipping ..\data\fma_small\006\006782.mp3 - already processed [331/8000]
# Skipping ..\data\fma_small\006\006783.mp3 - already processed [332/8000]
# Skipping ..\data\fma_small\006\006788.mp3 - already processed [333/8000]
# Skipping ..\data\fma_small\006\006802.mp3 - already processed [334/8000]
# Skipping ..\data\fma_small\006\006803.mp3 - already processed [335/8000]
# Skipping ..\data\fma_small\006\006854.mp3 - already processed [336/8000]
# Skipping ..\data\fma_small\006\006855.mp3 - already processed [337/8000]
# Skipping ..\data\fma_small\006\006856.mp3 - already processed [338/8000]
# Skipping ..\data\fma_small\006\006857.mp3 - already processed [339/8000]
# Skipping ..\data\fma_small\007\007011.mp3 - already processed [340/8000]
# Skipping ..\data\fma_small\007\007373.mp3 - already processed [341/8000]
# Skipping ..\data\fma_small\007\007374.mp3 - already processed [342/8000]
# Skipping ..\data\fma_small\007\007375.mp3 - already processed [343/8000]
# Skipping ..\data\fma_small\007\007376.mp3 - already processed [344/8000]
# Skipping ..\data\fma_small\007\007377.mp3 - already processed [345/8000]
# Skipping ..\data\fma_small\007\007378.mp3 - already processed [346/8000]
# Skipping ..\data\fma_small\007\007379.mp3 - already processed [347/8000]
# Skipping ..\data\fma_small\007\007381.mp3 - already processed [348/8000]
# Skipping ..\data\fma_small\007\007383.mp3 - already processed [349/8000]
# Skipping ..\data\fma_small\007\007385.mp3 - already processed [350/8000]
# Skipping ..\data\fma_small\007\007386.mp3 - already processed [351/8000]
# Skipping ..\data\fma_small\007\007388.mp3 - already processed [352/8000]
# Skipping ..\data\fma_small\007\007391.mp3 - already processed [353/8000]
# Skipping ..\data\fma_small\007\007393.mp3 - already processed [354/8000]
# Skipping ..\data\fma_small\007\007481.mp3 - already processed [355/8000]
# Skipping ..\data\fma_small\007\007482.mp3 - already processed [356/8000]
# Skipping ..\data\fma_small\007\007483.mp3 - already processed [357/8000]
# Skipping ..\data\fma_small\007\007487.mp3 - already processed [358/8000]
# Skipping ..\data\fma_small\007\007488.mp3 - already processed [359/8000]
# Skipping ..\data\fma_small\007\007489.mp3 - already processed [360/8000]
# Skipping ..\data\fma_small\007\007490.mp3 - already processed [361/8000]
# Skipping ..\data\fma_small\007\007491.mp3 - already processed [362/8000]
# Skipping ..\data\fma_small\007\007492.mp3 - already processed [363/8000]
# Skipping ..\data\fma_small\007\007495.mp3 - already processed [364/8000]
# Skipping ..\data\fma_small\007\007526.mp3 - already processed [365/8000]
# Skipping ..\data\fma_small\007\007527.mp3 - already processed [366/8000]
# Skipping ..\data\fma_small\007\007528.mp3 - already processed [367/8000]
# Skipping ..\data\fma_small\007\007529.mp3 - already processed [368/8000]
# Skipping ..\data\fma_small\007\007548.mp3 - already processed [369/8000]
# Skipping ..\data\fma_small\007\007554.mp3 - already processed [370/8000]
# Skipping ..\data\fma_small\007\007709.mp3 - already processed [371/8000]
# Skipping ..\data\fma_small\007\007710.mp3 - already processed [372/8000]
# Skipping ..\data\fma_small\007\007711.mp3 - already processed [373/8000]
# Skipping ..\data\fma_small\007\007712.mp3 - already processed [374/8000]
# Skipping ..\data\fma_small\007\007713.mp3 - already processed [375/8000]
# Skipping ..\data\fma_small\007\007872.mp3 - already processed [376/8000]
# Skipping ..\data\fma_small\008\008056.mp3 - already processed [377/8000]
# Skipping ..\data\fma_small\008\008208.mp3 - already processed [378/8000]
# Skipping ..\data\fma_small\008\008256.mp3 - already processed [379/8000]
# Skipping ..\data\fma_small\008\008259.mp3 - already processed [380/8000]
# Skipping ..\data\fma_small\008\008261.mp3 - already processed [381/8000]
# Skipping ..\data\fma_small\008\008345.mp3 - already processed [382/8000]
# Skipping ..\data\fma_small\008\008357.mp3 - already processed [383/8000]
# Skipping ..\data\fma_small\008\008363.mp3 - already processed [384/8000]
# Skipping ..\data\fma_small\008\008372.mp3 - already processed [385/8000]
# Skipping ..\data\fma_small\008\008416.mp3 - already processed [386/8000]
# Skipping ..\data\fma_small\009\009152.mp3 - already processed [387/8000]
# Skipping ..\data\fma_small\009\009155.mp3 - already processed [388/8000]
# Skipping ..\data\fma_small\009\009307.mp3 - already processed [389/8000]
# Skipping ..\data\fma_small\009\009476.mp3 - already processed [390/8000]
# Skipping ..\data\fma_small\009\009477.mp3 - already processed [391/8000]
# Skipping ..\data\fma_small\009\009491.mp3 - already processed [392/8000]
# Skipping ..\data\fma_small\009\009505.mp3 - already processed [393/8000]
# Skipping ..\data\fma_small\009\009511.mp3 - already processed [394/8000]
# Skipping ..\data\fma_small\009\009512.mp3 - already processed [395/8000]
# Skipping ..\data\fma_small\009\009513.mp3 - already processed [396/8000]
# Skipping ..\data\fma_small\009\009550.mp3 - already processed [397/8000]
# Skipping ..\data\fma_small\009\009553.mp3 - already processed [398/8000]
# Skipping ..\data\fma_small\009\009555.mp3 - already processed [399/8000]
# Skipping ..\data\fma_small\009\009557.mp3 - already processed [400/8000]
# Skipping ..\data\fma_small\009\009559.mp3 - already processed [401/8000]
# Skipping ..\data\fma_small\009\009560.mp3 - already processed [402/8000]
# Skipping ..\data\fma_small\009\009678.mp3 - already processed [403/8000]
# Skipping ..\data\fma_small\009\009721.mp3 - already processed [404/8000]
# Skipping ..\data\fma_small\009\009846.mp3 - already processed [405/8000]
# Skipping ..\data\fma_small\009\009887.mp3 - already processed [406/8000]
# Skipping ..\data\fma_small\009\009888.mp3 - already processed [407/8000]
# Skipping ..\data\fma_small\009\009918.mp3 - already processed [408/8000]
# Skipping ..\data\fma_small\009\009962.mp3 - already processed [409/8000]
# Skipping ..\data\fma_small\010\010186.mp3 - already processed [410/8000]
# Skipping ..\data\fma_small\010\010192.mp3 - already processed [411/8000]
# Skipping ..\data\fma_small\010\010250.mp3 - already processed [412/8000]
# Skipping ..\data\fma_small\010\010374.mp3 - already processed [413/8000]
# Skipping ..\data\fma_small\010\010375.mp3 - already processed [414/8000]
# Skipping ..\data\fma_small\010\010376.mp3 - already processed [415/8000]
# Skipping ..\data\fma_small\010\010377.mp3 - already processed [416/8000]
# Skipping ..\data\fma_small\010\010381.mp3 - already processed [417/8000]
# Skipping ..\data\fma_small\010\010382.mp3 - already processed [418/8000]
# Skipping ..\data\fma_small\010\010383.mp3 - already processed [419/8000]
# Skipping ..\data\fma_small\010\010384.mp3 - already processed [420/8000]
# Skipping ..\data\fma_small\010\010385.mp3 - already processed [421/8000]
# Skipping ..\data\fma_small\010\010386.mp3 - already processed [422/8000]
# Skipping ..\data\fma_small\010\010387.mp3 - already processed [423/8000]
# Skipping ..\data\fma_small\010\010388.mp3 - already processed [424/8000]
# Skipping ..\data\fma_small\010\010389.mp3 - already processed [425/8000]
# Skipping ..\data\fma_small\010\010435.mp3 - already processed [426/8000]
# Skipping ..\data\fma_small\010\010438.mp3 - already processed [427/8000]
# Skipping ..\data\fma_small\010\010439.mp3 - already processed [428/8000]
# Skipping ..\data\fma_small\010\010440.mp3 - already processed [429/8000]
# Skipping ..\data\fma_small\010\010441.mp3 - already processed [430/8000]
# Skipping ..\data\fma_small\010\010442.mp3 - already processed [431/8000]
# Skipping ..\data\fma_small\010\010443.mp3 - already processed [432/8000]
# Skipping ..\data\fma_small\010\010444.mp3 - already processed [433/8000]
# Skipping ..\data\fma_small\010\010447.mp3 - already processed [434/8000]
# Skipping ..\data\fma_small\010\010458.mp3 - already processed [435/8000]
# Skipping ..\data\fma_small\010\010480.mp3 - already processed [436/8000]
# Skipping ..\data\fma_small\010\010481.mp3 - already processed [437/8000]
# Skipping ..\data\fma_small\010\010485.mp3 - already processed [438/8000]
# Skipping ..\data\fma_small\010\010521.mp3 - already processed [439/8000]
# Skipping ..\data\fma_small\010\010527.mp3 - already processed [440/8000]
# Skipping ..\data\fma_small\010\010535.mp3 - already processed [441/8000]
# Skipping ..\data\fma_small\010\010541.mp3 - already processed [442/8000]
# Skipping ..\data\fma_small\010\010575.mp3 - already processed [443/8000]
# Skipping ..\data\fma_small\010\010577.mp3 - already processed [444/8000]
# Skipping ..\data\fma_small\010\010668.mp3 - already processed [445/8000]
# Skipping ..\data\fma_small\010\010669.mp3 - already processed [446/8000]
# Skipping ..\data\fma_small\010\010670.mp3 - already processed [447/8000]
# Skipping ..\data\fma_small\010\010671.mp3 - already processed [448/8000]
# Skipping ..\data\fma_small\010\010672.mp3 - already processed [449/8000]
# Skipping ..\data\fma_small\010\010673.mp3 - already processed [450/8000]
# Skipping ..\data\fma_small\010\010674.mp3 - already processed [451/8000]
# Skipping ..\data\fma_small\010\010675.mp3 - already processed [452/8000]
# Skipping ..\data\fma_small\010\010676.mp3 - already processed [453/8000]
# Skipping ..\data\fma_small\010\010677.mp3 - already processed [454/8000]
# Skipping ..\data\fma_small\010\010678.mp3 - already processed [455/8000]
# Skipping ..\data\fma_small\010\010679.mp3 - already processed [456/8000]
# Skipping ..\data\fma_small\010\010682.mp3 - already processed [457/8000]
# Skipping ..\data\fma_small\010\010684.mp3 - already processed [458/8000]
# Skipping ..\data\fma_small\010\010693.mp3 - already processed [459/8000]
# Skipping ..\data\fma_small\010\010694.mp3 - already processed [460/8000]
# Skipping ..\data\fma_small\010\010695.mp3 - already processed [461/8000]
# Skipping ..\data\fma_small\010\010696.mp3 - already processed [462/8000]
# Skipping ..\data\fma_small\010\010697.mp3 - already processed [463/8000]
# Skipping ..\data\fma_small\010\010698.mp3 - already processed [464/8000]
# Skipping ..\data\fma_small\010\010699.mp3 - already processed [465/8000]
# Skipping ..\data\fma_small\010\010805.mp3 - already processed [466/8000]
# Skipping ..\data\fma_small\010\010806.mp3 - already processed [467/8000]
# Skipping ..\data\fma_small\010\010807.mp3 - already processed [468/8000]
# Skipping ..\data\fma_small\010\010808.mp3 - already processed [469/8000]
# Skipping ..\data\fma_small\010\010809.mp3 - already processed [470/8000]
# Skipping ..\data\fma_small\010\010810.mp3 - already processed [471/8000]
# Skipping ..\data\fma_small\010\010983.mp3 - already processed [472/8000]
# Skipping ..\data\fma_small\010\010992.mp3 - already processed [473/8000]
# Skipping ..\data\fma_small\010\010993.mp3 - already processed [474/8000]
# Skipping ..\data\fma_small\011\011019.mp3 - already processed [475/8000]
# Skipping ..\data\fma_small\011\011020.mp3 - already processed [476/8000]
# Skipping ..\data\fma_small\011\011059.mp3 - already processed [477/8000]
# Skipping ..\data\fma_small\011\011198.mp3 - already processed [478/8000]
# Skipping ..\data\fma_small\011\011199.mp3 - already processed [479/8000]
# Skipping ..\data\fma_small\011\011200.mp3 - already processed [480/8000]
# Skipping ..\data\fma_small\011\011204.mp3 - already processed [481/8000]
# Skipping ..\data\fma_small\011\011206.mp3 - already processed [482/8000]
# Skipping ..\data\fma_small\011\011234.mp3 - already processed [483/8000]
# Skipping ..\data\fma_small\011\011237.mp3 - already processed [484/8000]
# Skipping ..\data\fma_small\011\011239.mp3 - already processed [485/8000]
# Skipping ..\data\fma_small\011\011242.mp3 - already processed [486/8000]
# Skipping ..\data\fma_small\011\011261.mp3 - already processed [487/8000]
# Skipping ..\data\fma_small\011\011262.mp3 - already processed [488/8000]
# Skipping ..\data\fma_small\011\011264.mp3 - already processed [489/8000]
# Skipping ..\data\fma_small\011\011268.mp3 - already processed [490/8000]
# Skipping ..\data\fma_small\011\011298.mp3 - already processed [491/8000]
# Skipping ..\data\fma_small\011\011299.mp3 - already processed [492/8000]
# Skipping ..\data\fma_small\011\011306.mp3 - already processed [493/8000]
# Skipping ..\data\fma_small\011\011333.mp3 - already processed [494/8000]
# Skipping ..\data\fma_small\011\011334.mp3 - already processed [495/8000]
# Skipping ..\data\fma_small\011\011503.mp3 - already processed [496/8000]
# Skipping ..\data\fma_small\011\011504.mp3 - already processed [497/8000]
# Skipping ..\data\fma_small\011\011505.mp3 - already processed [498/8000]
# Skipping ..\data\fma_small\011\011508.mp3 - already processed [499/8000]
# Skipping ..\data\fma_small\011\011544.mp3 - already processed [500/8000]
# Skipping ..\data\fma_small\011\011638.mp3 - already processed [501/8000]
# Skipping ..\data\fma_small\011\011671.mp3 - already processed [502/8000]
# Skipping ..\data\fma_small\011\011672.mp3 - already processed [503/8000]
# Skipping ..\data\fma_small\011\011673.mp3 - already processed [504/8000]
# Skipping ..\data\fma_small\011\011674.mp3 - already processed [505/8000]
# Skipping ..\data\fma_small\011\011675.mp3 - already processed [506/8000]
# Skipping ..\data\fma_small\011\011677.mp3 - already processed [507/8000]
# Skipping ..\data\fma_small\011\011679.mp3 - already processed [508/8000]
# Skipping ..\data\fma_small\011\011681.mp3 - already processed [509/8000]
# Skipping ..\data\fma_small\011\011682.mp3 - already processed [510/8000]
# Skipping ..\data\fma_small\011\011683.mp3 - already processed [511/8000]
# Skipping ..\data\fma_small\011\011763.mp3 - already processed [512/8000]
# Skipping ..\data\fma_small\011\011764.mp3 - already processed [513/8000]
# Skipping ..\data\fma_small\011\011765.mp3 - already processed [514/8000]
# Skipping ..\data\fma_small\011\011766.mp3 - already processed [515/8000]
# Skipping ..\data\fma_small\011\011767.mp3 - already processed [516/8000]
# Skipping ..\data\fma_small\011\011768.mp3 - already processed [517/8000]
# Skipping ..\data\fma_small\011\011769.mp3 - already processed [518/8000]
# Skipping ..\data\fma_small\011\011770.mp3 - already processed [519/8000]
# Skipping ..\data\fma_small\011\011771.mp3 - already processed [520/8000]
# Skipping ..\data\fma_small\011\011772.mp3 - already processed [521/8000]
# Skipping ..\data\fma_small\011\011773.mp3 - already processed [522/8000]
# Skipping ..\data\fma_small\011\011774.mp3 - already processed [523/8000]
# Skipping ..\data\fma_small\011\011775.mp3 - already processed [524/8000]
# Skipping ..\data\fma_small\011\011776.mp3 - already processed [525/8000]
# Skipping ..\data\fma_small\011\011777.mp3 - already processed [526/8000]
# Skipping ..\data\fma_small\011\011778.mp3 - already processed [527/8000]
# Skipping ..\data\fma_small\011\011779.mp3 - already processed [528/8000]
# Skipping ..\data\fma_small\011\011780.mp3 - already processed [529/8000]
# Skipping ..\data\fma_small\011\011781.mp3 - already processed [530/8000]
# Skipping ..\data\fma_small\011\011782.mp3 - already processed [531/8000]
# Skipping ..\data\fma_small\011\011783.mp3 - already processed [532/8000]
# Skipping ..\data\fma_small\011\011784.mp3 - already processed [533/8000]
# Skipping ..\data\fma_small\011\011785.mp3 - already processed [534/8000]
# Skipping ..\data\fma_small\011\011786.mp3 - already processed [535/8000]
# Skipping ..\data\fma_small\011\011787.mp3 - already processed [536/8000]
# Skipping ..\data\fma_small\011\011788.mp3 - already processed [537/8000]
# Skipping ..\data\fma_small\011\011789.mp3 - already processed [538/8000]
# Skipping ..\data\fma_small\011\011790.mp3 - already processed [539/8000]
# Skipping ..\data\fma_small\011\011791.mp3 - already processed [540/8000]
# Skipping ..\data\fma_small\011\011792.mp3 - already processed [541/8000]
# Skipping ..\data\fma_small\011\011793.mp3 - already processed [542/8000]
# Skipping ..\data\fma_small\011\011794.mp3 - already processed [543/8000]
# Skipping ..\data\fma_small\011\011795.mp3 - already processed [544/8000]
# Skipping ..\data\fma_small\011\011803.mp3 - already processed [545/8000]
# Skipping ..\data\fma_small\011\011818.mp3 - already processed [546/8000]
# Skipping ..\data\fma_small\011\011839.mp3 - already processed [547/8000]
# Skipping ..\data\fma_small\011\011861.mp3 - already processed [548/8000]
# Skipping ..\data\fma_small\011\011862.mp3 - already processed [549/8000]
# Skipping ..\data\fma_small\011\011867.mp3 - already processed [550/8000]
# Skipping ..\data\fma_small\011\011868.mp3 - already processed [551/8000]
# Skipping ..\data\fma_small\011\011916.mp3 - already processed [552/8000]
# Skipping ..\data\fma_small\011\011917.mp3 - already processed [553/8000]
# Skipping ..\data\fma_small\011\011918.mp3 - already processed [554/8000]
# Skipping ..\data\fma_small\011\011919.mp3 - already processed [555/8000]
# Skipping ..\data\fma_small\011\011920.mp3 - already processed [556/8000]
# Skipping ..\data\fma_small\011\011921.mp3 - already processed [557/8000]
# Skipping ..\data\fma_small\011\011922.mp3 - already processed [558/8000]
# Skipping ..\data\fma_small\011\011933.mp3 - already processed [559/8000]
# Skipping ..\data\fma_small\011\011937.mp3 - already processed [560/8000]
# Skipping ..\data\fma_small\011\011942.mp3 - already processed [561/8000]
# Skipping ..\data\fma_small\011\011946.mp3 - already processed [562/8000]
# Skipping ..\data\fma_small\011\011947.mp3 - already processed [563/8000]
# Skipping ..\data\fma_small\011\011951.mp3 - already processed [564/8000]
# Skipping ..\data\fma_small\012\012045.mp3 - already processed [565/8000]
# Skipping ..\data\fma_small\012\012046.mp3 - already processed [566/8000]
# Skipping ..\data\fma_small\012\012047.mp3 - already processed [567/8000]
# Skipping ..\data\fma_small\012\012048.mp3 - already processed [568/8000]
# Skipping ..\data\fma_small\012\012049.mp3 - already processed [569/8000]
# Skipping ..\data\fma_small\012\012050.mp3 - already processed [570/8000]
# Skipping ..\data\fma_small\012\012051.mp3 - already processed [571/8000]
# Skipping ..\data\fma_small\012\012052.mp3 - already processed [572/8000]
# Skipping ..\data\fma_small\012\012053.mp3 - already processed [573/8000]
# Skipping ..\data\fma_small\012\012058.mp3 - already processed [574/8000]
# Skipping ..\data\fma_small\012\012059.mp3 - already processed [575/8000]
# Skipping ..\data\fma_small\012\012060.mp3 - already processed [576/8000]
# Skipping ..\data\fma_small\012\012061.mp3 - already processed [577/8000]
# Skipping ..\data\fma_small\012\012062.mp3 - already processed [578/8000]
# Skipping ..\data\fma_small\012\012064.mp3 - already processed [579/8000]
# Skipping ..\data\fma_small\012\012065.mp3 - already processed [580/8000]
# Skipping ..\data\fma_small\012\012066.mp3 - already processed [581/8000]
# Skipping ..\data\fma_small\012\012067.mp3 - already processed [582/8000]
# Skipping ..\data\fma_small\012\012109.mp3 - already processed [583/8000]
# Skipping ..\data\fma_small\012\012146.mp3 - already processed [584/8000]
# Skipping ..\data\fma_small\012\012147.mp3 - already processed [585/8000]
# Skipping ..\data\fma_small\012\012173.mp3 - already processed [586/8000]
# Skipping ..\data\fma_small\012\012174.mp3 - already processed [587/8000]
# Skipping ..\data\fma_small\012\012179.mp3 - already processed [588/8000]
# Skipping ..\data\fma_small\012\012188.mp3 - already processed [589/8000]
# Skipping ..\data\fma_small\012\012189.mp3 - already processed [590/8000]
# Skipping ..\data\fma_small\012\012346.mp3 - already processed [591/8000]
# Skipping ..\data\fma_small\012\012348.mp3 - already processed [592/8000]
# Skipping ..\data\fma_small\012\012349.mp3 - already processed [593/8000]
# Skipping ..\data\fma_small\012\012350.mp3 - already processed [594/8000]
# Skipping ..\data\fma_small\012\012351.mp3 - already processed [595/8000]
# Skipping ..\data\fma_small\012\012352.mp3 - already processed [596/8000]
# Skipping ..\data\fma_small\012\012353.mp3 - already processed [597/8000]
# Skipping ..\data\fma_small\012\012355.mp3 - already processed [598/8000]
# Skipping ..\data\fma_small\012\012376.mp3 - already processed [599/8000]
# Skipping ..\data\fma_small\012\012387.mp3 - already processed [600/8000]
# Skipping ..\data\fma_small\012\012390.mp3 - already processed [601/8000]
# Skipping ..\data\fma_small\012\012394.mp3 - already processed [602/8000]
# Skipping ..\data\fma_small\012\012481.mp3 - already processed [603/8000]
# Skipping ..\data\fma_small\012\012482.mp3 - already processed [604/8000]
# Skipping ..\data\fma_small\012\012484.mp3 - already processed [605/8000]
# Skipping ..\data\fma_small\012\012485.mp3 - already processed [606/8000]
# Skipping ..\data\fma_small\012\012486.mp3 - already processed [607/8000]
# Skipping ..\data\fma_small\012\012487.mp3 - already processed [608/8000]
# Skipping ..\data\fma_small\012\012488.mp3 - already processed [609/8000]
# Skipping ..\data\fma_small\012\012489.mp3 - already processed [610/8000]
# Skipping ..\data\fma_small\012\012490.mp3 - already processed [611/8000]
# Skipping ..\data\fma_small\012\012508.mp3 - already processed [612/8000]
# Skipping ..\data\fma_small\012\012513.mp3 - already processed [613/8000]
# Skipping ..\data\fma_small\012\012514.mp3 - already processed [614/8000]
# Skipping ..\data\fma_small\012\012518.mp3 - already processed [615/8000]
# Skipping ..\data\fma_small\012\012521.mp3 - already processed [616/8000]
# Skipping ..\data\fma_small\012\012526.mp3 - already processed [617/8000]
# Skipping ..\data\fma_small\012\012527.mp3 - already processed [618/8000]
# Skipping ..\data\fma_small\012\012530.mp3 - already processed [619/8000]
# Skipping ..\data\fma_small\012\012531.mp3 - already processed [620/8000]
# Skipping ..\data\fma_small\012\012532.mp3 - already processed [621/8000]
# Skipping ..\data\fma_small\012\012537.mp3 - already processed [622/8000]
# Skipping ..\data\fma_small\012\012551.mp3 - already processed [623/8000]
# Skipping ..\data\fma_small\012\012552.mp3 - already processed [624/8000]
# Skipping ..\data\fma_small\012\012654.mp3 - already processed [625/8000]
# Skipping ..\data\fma_small\012\012690.mp3 - already processed [626/8000]
# Skipping ..\data\fma_small\012\012691.mp3 - already processed [627/8000]
# Skipping ..\data\fma_small\012\012692.mp3 - already processed [628/8000]
# Skipping ..\data\fma_small\012\012737.mp3 - already processed [629/8000]
# Skipping ..\data\fma_small\012\012985.mp3 - already processed [630/8000]
# Skipping ..\data\fma_small\012\012986.mp3 - already processed [631/8000]
# Skipping ..\data\fma_small\013\013191.mp3 - already processed [632/8000]
# Skipping ..\data\fma_small\013\013197.mp3 - already processed [633/8000]
# Skipping ..\data\fma_small\013\013199.mp3 - already processed [634/8000]
# Skipping ..\data\fma_small\013\013201.mp3 - already processed [635/8000]
# Skipping ..\data\fma_small\013\013218.mp3 - already processed [636/8000]
# Skipping ..\data\fma_small\013\013220.mp3 - already processed [637/8000]
# Skipping ..\data\fma_small\013\013325.mp3 - already processed [638/8000]
# Skipping ..\data\fma_small\013\013328.mp3 - already processed [639/8000]
# Skipping ..\data\fma_small\013\013362.mp3 - already processed [640/8000]
# Skipping ..\data\fma_small\013\013378.mp3 - already processed [641/8000]
# Skipping ..\data\fma_small\013\013474.mp3 - already processed [642/8000]
# Skipping ..\data\fma_small\013\013537.mp3 - already processed [643/8000]
# Skipping ..\data\fma_small\013\013538.mp3 - already processed [644/8000]
# Skipping ..\data\fma_small\013\013539.mp3 - already processed [645/8000]
# Skipping ..\data\fma_small\013\013540.mp3 - already processed [646/8000]
# Skipping ..\data\fma_small\013\013556.mp3 - already processed [647/8000]
# Skipping ..\data\fma_small\013\013561.mp3 - already processed [648/8000]
# Skipping ..\data\fma_small\013\013562.mp3 - already processed [649/8000]
# Skipping ..\data\fma_small\013\013566.mp3 - already processed [650/8000]
# Skipping ..\data\fma_small\013\013571.mp3 - already processed [651/8000]
# Skipping ..\data\fma_small\013\013578.mp3 - already processed [652/8000]
# Skipping ..\data\fma_small\013\013591.mp3 - already processed [653/8000]
# Skipping ..\data\fma_small\013\013596.mp3 - already processed [654/8000]
# Skipping ..\data\fma_small\013\013666.mp3 - already processed [655/8000]
# Skipping ..\data\fma_small\013\013668.mp3 - already processed [656/8000]
# Skipping ..\data\fma_small\013\013670.mp3 - already processed [657/8000]
# Skipping ..\data\fma_small\013\013706.mp3 - already processed [658/8000]
# ...
# Skipping ..\data\fma_small\146\146970.mp3 - already processed [7795/8000]
# Skipping ..\data\fma_small\146\146988.mp3 - already processed [7796/8000]
# Skipping ..\data\fma_small\146\146989.mp3 - already processed [7797/8000]
# Skipping ..\data\fma_small\147\147020.mp3 - already processed [7798/8000]
# Skipping ..\data\fma_small\147\147021.mp3 - already processed [7799/8000]
# Skipping ..\data\fma_small\147\147022.mp3 - already processed [7800/8000]
# Skipping ..\data\fma_small\147\147023.mp3 - already processed [7801/8000]
# Skipping ..\data\fma_small\147\147024.mp3 - already processed [7802/8000]
# Skipping ..\data\fma_small\147\147059.mp3 - already processed [7803/8000]
# Skipping ..\data\fma_small\147\147085.mp3 - already processed [7804/8000]
# Skipping ..\data\fma_small\147\147086.mp3 - already processed [7805/8000]
# Skipping ..\data\fma_small\147\147087.mp3 - already processed [7806/8000]
# Skipping ..\data\fma_small\147\147126.mp3 - already processed [7807/8000]
# Skipping ..\data\fma_small\147\147191.mp3 - already processed [7808/8000]
# Skipping ..\data\fma_small\147\147261.mp3 - already processed [7809/8000]
# Skipping ..\data\fma_small\147\147265.mp3 - already processed [7810/8000]
# Skipping ..\data\fma_small\147\147267.mp3 - already processed [7811/8000]
# Skipping ..\data\fma_small\147\147268.mp3 - already processed [7812/8000]
# Skipping ..\data\fma_small\147\147269.mp3 - already processed [7813/8000]
# Skipping ..\data\fma_small\147\147295.mp3 - already processed [7814/8000]
# Skipping ..\data\fma_small\147\147309.mp3 - already processed [7815/8000]
# Skipping ..\data\fma_small\147\147409.mp3 - already processed [7816/8000]
# Skipping ..\data\fma_small\147\147412.mp3 - already processed [7817/8000]
# Skipping ..\data\fma_small\147\147413.mp3 - already processed [7818/8000]
# Skipping ..\data\fma_small\147\147780.mp3 - already processed [7819/8000]
# Skipping ..\data\fma_small\147\147815.mp3 - already processed [7820/8000]
# Skipping ..\data\fma_small\147\147886.mp3 - already processed [7821/8000]
# Skipping ..\data\fma_small\147\147956.mp3 - already processed [7822/8000]
# Skipping ..\data\fma_small\148\148002.mp3 - already processed [7823/8000]
# Skipping ..\data\fma_small\148\148028.mp3 - already processed [7824/8000]
# Skipping ..\data\fma_small\148\148031.mp3 - already processed [7825/8000]
# Skipping ..\data\fma_small\148\148032.mp3 - already processed [7826/8000]
# Skipping ..\data\fma_small\148\148066.mp3 - already processed [7827/8000]
# Skipping ..\data\fma_small\148\148070.mp3 - already processed [7828/8000]
# Skipping ..\data\fma_small\148\148074.mp3 - already processed [7829/8000]
# Skipping ..\data\fma_small\148\148075.mp3 - already processed [7830/8000]
# Skipping ..\data\fma_small\148\148076.mp3 - already processed [7831/8000]
# Skipping ..\data\fma_small\148\148077.mp3 - already processed [7832/8000]
# Skipping ..\data\fma_small\148\148078.mp3 - already processed [7833/8000]
# Skipping ..\data\fma_small\148\148079.mp3 - already processed [7834/8000]
# Skipping ..\data\fma_small\148\148082.mp3 - already processed [7835/8000]
# Skipping ..\data\fma_small\148\148099.mp3 - already processed [7836/8000]
# Skipping ..\data\fma_small\148\148112.mp3 - already processed [7837/8000]
# Skipping ..\data\fma_small\148\148113.mp3 - already processed [7838/8000]
# Skipping ..\data\fma_small\148\148114.mp3 - already processed [7839/8000]
# Skipping ..\data\fma_small\148\148120.mp3 - already processed [7840/8000]
# Skipping ..\data\fma_small\148\148121.mp3 - already processed [7841/8000]
# Skipping ..\data\fma_small\148\148124.mp3 - already processed [7842/8000]
# Skipping ..\data\fma_small\148\148130.mp3 - already processed [7843/8000]
# Skipping ..\data\fma_small\148\148131.mp3 - already processed [7844/8000]
# Skipping ..\data\fma_small\148\148132.mp3 - already processed [7845/8000]
# Skipping ..\data\fma_small\148\148133.mp3 - already processed [7846/8000]
# Skipping ..\data\fma_small\148\148168.mp3 - already processed [7847/8000]
# Skipping ..\data\fma_small\148\148186.mp3 - already processed [7848/8000]
# Skipping ..\data\fma_small\148\148187.mp3 - already processed [7849/8000]
# Skipping ..\data\fma_small\148\148190.mp3 - already processed [7850/8000]
# Skipping ..\data\fma_small\148\148208.mp3 - already processed [7851/8000]
# Skipping ..\data\fma_small\148\148210.mp3 - already processed [7852/8000]
# Skipping ..\data\fma_small\148\148211.mp3 - already processed [7853/8000]
# Skipping ..\data\fma_small\148\148212.mp3 - already processed [7854/8000]
# Skipping ..\data\fma_small\148\148213.mp3 - already processed [7855/8000]
# Skipping ..\data\fma_small\148\148214.mp3 - already processed [7856/8000]
# Skipping ..\data\fma_small\148\148215.mp3 - already processed [7857/8000]
# Skipping ..\data\fma_small\148\148216.mp3 - already processed [7858/8000]
# Skipping ..\data\fma_small\148\148217.mp3 - already processed [7859/8000]
# Skipping ..\data\fma_small\148\148218.mp3 - already processed [7860/8000]
# Skipping ..\data\fma_small\148\148231.mp3 - already processed [7861/8000]
# Skipping ..\data\fma_small\148\148233.mp3 - already processed [7862/8000]
# Skipping ..\data\fma_small\148\148234.mp3 - already processed [7863/8000]
# Skipping ..\data\fma_small\148\148235.mp3 - already processed [7864/8000]
# Skipping ..\data\fma_small\148\148246.mp3 - already processed [7865/8000]
# Skipping ..\data\fma_small\148\148285.mp3 - already processed [7866/8000]
# Skipping ..\data\fma_small\148\148286.mp3 - already processed [7867/8000]
# Skipping ..\data\fma_small\148\148287.mp3 - already processed [7868/8000]
# Skipping ..\data\fma_small\148\148288.mp3 - already processed [7869/8000]
# Skipping ..\data\fma_small\148\148289.mp3 - already processed [7870/8000]
# Skipping ..\data\fma_small\148\148290.mp3 - already processed [7871/8000]
# Skipping ..\data\fma_small\148\148302.mp3 - already processed [7872/8000]
# Skipping ..\data\fma_small\148\148303.mp3 - already processed [7873/8000]
# Skipping ..\data\fma_small\148\148305.mp3 - already processed [7874/8000]
# Skipping ..\data\fma_small\148\148429.mp3 - already processed [7875/8000]
# Skipping ..\data\fma_small\148\148430.mp3 - already processed [7876/8000]
# Skipping ..\data\fma_small\148\148439.mp3 - already processed [7877/8000]
# Skipping ..\data\fma_small\148\148441.mp3 - already processed [7878/8000]
# Skipping ..\data\fma_small\148\148443.mp3 - already processed [7879/8000]
# Skipping ..\data\fma_small\148\148444.mp3 - already processed [7880/8000]
# Skipping ..\data\fma_small\148\148510.mp3 - already processed [7881/8000]
# Skipping ..\data\fma_small\148\148513.mp3 - already processed [7882/8000]
# Skipping ..\data\fma_small\148\148514.mp3 - already processed [7883/8000]
# Skipping ..\data\fma_small\148\148516.mp3 - already processed [7884/8000]
# Skipping ..\data\fma_small\148\148517.mp3 - already processed [7885/8000]
# Skipping ..\data\fma_small\148\148518.mp3 - already processed [7886/8000]
# Skipping ..\data\fma_small\148\148519.mp3 - already processed [7887/8000]
# Skipping ..\data\fma_small\148\148532.mp3 - already processed [7888/8000]
# Skipping ..\data\fma_small\148\148535.mp3 - already processed [7889/8000]
# Skipping ..\data\fma_small\148\148536.mp3 - already processed [7890/8000]
# Skipping ..\data\fma_small\148\148537.mp3 - already processed [7891/8000]
# Skipping ..\data\fma_small\148\148584.mp3 - already processed [7892/8000]
# Skipping ..\data\fma_small\148\148585.mp3 - already processed [7893/8000]
# Skipping ..\data\fma_small\148\148586.mp3 - already processed [7894/8000]
# Skipping ..\data\fma_small\148\148587.mp3 - already processed [7895/8000]
# Skipping ..\data\fma_small\148\148602.mp3 - already processed [7896/8000]
# Skipping ..\data\fma_small\148\148603.mp3 - already processed [7897/8000]
# Skipping ..\data\fma_small\148\148604.mp3 - already processed [7898/8000]
# Skipping ..\data\fma_small\148\148605.mp3 - already processed [7899/8000]
# Skipping ..\data\fma_small\148\148606.mp3 - already processed [7900/8000]
# Skipping ..\data\fma_small\148\148607.mp3 - already processed [7901/8000]
# Skipping ..\data\fma_small\148\148608.mp3 - already processed [7902/8000]
# Skipping ..\data\fma_small\148\148609.mp3 - already processed [7903/8000]
# Skipping ..\data\fma_small\148\148610.mp3 - already processed [7904/8000]
# Skipping ..\data\fma_small\148\148611.mp3 - already processed [7905/8000]
# Skipping ..\data\fma_small\148\148612.mp3 - already processed [7906/8000]
# Skipping ..\data\fma_small\148\148613.mp3 - already processed [7907/8000]
# Skipping ..\data\fma_small\148\148773.mp3 - already processed [7908/8000]
# Skipping ..\data\fma_small\149\149075.mp3 - already processed [7909/8000]
# Skipping ..\data\fma_small\149\149078.mp3 - already processed [7910/8000]
# Skipping ..\data\fma_small\149\149082.mp3 - already processed [7911/8000]
# Skipping ..\data\fma_small\149\149083.mp3 - already processed [7912/8000]
# Skipping ..\data\fma_small\149\149099.mp3 - already processed [7913/8000]
# Skipping ..\data\fma_small\149\149100.mp3 - already processed [7914/8000]
# Skipping ..\data\fma_small\149\149101.mp3 - already processed [7915/8000]
# Skipping ..\data\fma_small\149\149102.mp3 - already processed [7916/8000]
# Skipping ..\data\fma_small\149\149103.mp3 - already processed [7917/8000]
# Skipping ..\data\fma_small\149\149118.mp3 - already processed [7918/8000]
# Skipping ..\data\fma_small\149\149124.mp3 - already processed [7919/8000]
# Skipping ..\data\fma_small\149\149138.mp3 - already processed [7920/8000]
# Skipping ..\data\fma_small\149\149139.mp3 - already processed [7921/8000]
# Skipping ..\data\fma_small\149\149140.mp3 - already processed [7922/8000]
# Skipping ..\data\fma_small\149\149141.mp3 - already processed [7923/8000]
# Skipping ..\data\fma_small\149\149142.mp3 - already processed [7924/8000]
# Skipping ..\data\fma_small\149\149143.mp3 - already processed [7925/8000]
# Skipping ..\data\fma_small\149\149185.mp3 - already processed [7926/8000]
# Skipping ..\data\fma_small\149\149369.mp3 - already processed [7927/8000]
# Skipping ..\data\fma_small\149\149370.mp3 - already processed [7928/8000]
# Skipping ..\data\fma_small\149\149416.mp3 - already processed [7929/8000]
# Skipping ..\data\fma_small\149\149417.mp3 - already processed [7930/8000]
# Skipping ..\data\fma_small\149\149422.mp3 - already processed [7931/8000]
# Skipping ..\data\fma_small\149\149452.mp3 - already processed [7932/8000]
# Skipping ..\data\fma_small\149\149488.mp3 - already processed [7933/8000]
# Skipping ..\data\fma_small\149\149523.mp3 - already processed [7934/8000]
# Skipping ..\data\fma_small\149\149623.mp3 - already processed [7935/8000]
# Skipping ..\data\fma_small\149\149625.mp3 - already processed [7936/8000]
# Skipping ..\data\fma_small\149\149626.mp3 - already processed [7937/8000]
# Skipping ..\data\fma_small\149\149687.mp3 - already processed [7938/8000]
# Skipping ..\data\fma_small\149\149689.mp3 - already processed [7939/8000]
# Skipping ..\data\fma_small\149\149690.mp3 - already processed [7940/8000]
# Skipping ..\data\fma_small\149\149700.mp3 - already processed [7941/8000]
# Skipping ..\data\fma_small\149\149701.mp3 - already processed [7942/8000]
# Skipping ..\data\fma_small\149\149712.mp3 - already processed [7943/8000]
# Skipping ..\data\fma_small\149\149714.mp3 - already processed [7944/8000]
# Skipping ..\data\fma_small\149\149727.mp3 - already processed [7945/8000]
# Skipping ..\data\fma_small\149\149750.mp3 - already processed [7946/8000]
# Skipping ..\data\fma_small\149\149775.mp3 - already processed [7947/8000]
# Skipping ..\data\fma_small\149\149776.mp3 - already processed [7948/8000]
# Skipping ..\data\fma_small\149\149777.mp3 - already processed [7949/8000]
# Skipping ..\data\fma_small\149\149778.mp3 - already processed [7950/8000]
# Skipping ..\data\fma_small\149\149842.mp3 - already processed [7951/8000]
# Skipping ..\data\fma_small\149\149951.mp3 - already processed [7952/8000]
# Skipping ..\data\fma_small\149\149953.mp3 - already processed [7953/8000]
# Skipping ..\data\fma_small\150\150015.mp3 - already processed [7954/8000]
# Skipping ..\data\fma_small\150\150017.mp3 - already processed [7955/8000]
# Skipping ..\data\fma_small\150\150018.mp3 - already processed [7956/8000]
# Skipping ..\data\fma_small\150\150062.mp3 - already processed [7957/8000]
# Skipping ..\data\fma_small\150\150063.mp3 - already processed [7958/8000]
# Skipping ..\data\fma_small\150\150064.mp3 - already processed [7959/8000]
# Skipping ..\data\fma_small\150\150073.mp3 - already processed [7960/8000]
# Skipping ..\data\fma_small\150\150078.mp3 - already processed [7961/8000]
# Skipping ..\data\fma_small\150\150079.mp3 - already processed [7962/8000]
# Skipping ..\data\fma_small\150\150080.mp3 - already processed [7963/8000]
# Skipping ..\data\fma_small\150\150265.mp3 - already processed [7964/8000]
# Skipping ..\data\fma_small\150\150266.mp3 - already processed [7965/8000]
# Skipping ..\data\fma_small\150\150267.mp3 - already processed [7966/8000]
# Skipping ..\data\fma_small\150\150268.mp3 - already processed [7967/8000]
# Skipping ..\data\fma_small\150\150287.mp3 - already processed [7968/8000]
# Skipping ..\data\fma_small\150\150288.mp3 - already processed [7969/8000]
# Skipping ..\data\fma_small\151\151404.mp3 - already processed [7970/8000]
# Skipping ..\data\fma_small\152\152103.mp3 - already processed [7971/8000]
# Skipping ..\data\fma_small\152\152253.mp3 - already processed [7972/8000]
# Skipping ..\data\fma_small\152\152254.mp3 - already processed [7973/8000]
# Skipping ..\data\fma_small\152\152258.mp3 - already processed [7974/8000]
# Skipping ..\data\fma_small\152\152261.mp3 - already processed [7975/8000]
# Skipping ..\data\fma_small\152\152262.mp3 - already processed [7976/8000]
# Skipping ..\data\fma_small\152\152324.mp3 - already processed [7977/8000]
# Skipping ..\data\fma_small\152\152418.mp3 - already processed [7978/8000]
# Skipping ..\data\fma_small\152\152425.mp3 - already processed [7979/8000]
# Skipping ..\data\fma_small\152\152480.mp3 - already processed [7980/8000]
# Skipping ..\data\fma_small\152\152543.mp3 - already processed [7981/8000]
# Skipping ..\data\fma_small\152\152545.mp3 - already processed [7982/8000]
# Skipping ..\data\fma_small\152\152568.mp3 - already processed [7983/8000]
# Skipping ..\data\fma_small\152\152569.mp3 - already processed [7984/8000]
# Skipping ..\data\fma_small\152\152570.mp3 - already processed [7985/8000]
# Skipping ..\data\fma_small\153\153337.mp3 - already processed [7986/8000]
# Skipping ..\data\fma_small\153\153383.mp3 - already processed [7987/8000]
# Skipping ..\data\fma_small\153\153452.mp3 - already processed [7988/8000]
# Skipping ..\data\fma_small\153\153946.mp3 - already processed [7989/8000]
# Skipping ..\data\fma_small\153\153955.mp3 - already processed [7990/8000]
# Skipping ..\data\fma_small\153\153956.mp3 - already processed [7991/8000]
# Skipping ..\data\fma_small\154\154303.mp3 - already processed [7992/8000]
# Skipping ..\data\fma_small\154\154305.mp3 - already processed [7993/8000]
# Skipping ..\data\fma_small\154\154306.mp3 - already processed [7994/8000]
# Skipping ..\data\fma_small\154\154307.mp3 - already processed [7995/8000]
# Skipping ..\data\fma_small\154\154308.mp3 - already processed [7996/8000]
# Skipping ..\data\fma_small\154\154309.mp3 - already processed [7997/8000]
# Skipping ..\data\fma_small\154\154413.mp3 - already processed [7998/8000]
# Skipping ..\data\fma_small\154\154414.mp3 - already processed [7999/8000]
# Skipping ..\data\fma_small\155\155066.mp3 - already processed [8000/8000]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 79
#      75     labels.append(file)
#      78 # Write embeddings to disk
# ---> 79 embeds = np.vstack(embeds)
#      80 labels = np.array(labels)
#      81 np.savez_compressed("embeddings_large.npz", embeds=embeds, labels=labels)
#
# File c:\Users\james\OneDrive\Documents\GitHub\Individual-Project-Win\env\Lib\site-packages\numpy\_core\shape_base.py:291, in vstack(tup, dtype, casting)
#     289 if not isinstance(arrs, tuple):
#     290     arrs = (arrs,)
# --> 291 return _nx.concatenate(arrs, 0, dtype=dtype, casting=casting)
#
# ValueError: need at least one array to concatenate
